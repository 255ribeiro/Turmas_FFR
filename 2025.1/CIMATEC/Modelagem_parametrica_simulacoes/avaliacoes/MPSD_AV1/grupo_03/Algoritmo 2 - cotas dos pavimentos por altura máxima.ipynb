# %%
from math import ceil #importanto função ceil

#  Av1 Modelagem parametrica e Simulações digitais
# equipe: Luiza e Victor
# aluna 1: Luiza Seabra Batista Henriques Ramos
# aluno 2: Victor Santos da Silva


cota_piso = float (input("entre com a cota do terreno: "))
pap = float (input("entre com a distância piso a piso: "))
cota_max = float (input("entre o valor máximo de altura: "))

count = 0
while cota_piso <= cota_max:
    count = count + 1
    print(cota_piso)
    cota_piso = cota_piso + pap
print ("cota de pisos: ", count)
