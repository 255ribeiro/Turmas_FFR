# %%
#  Av1 Modelagem parametrica e Simulações digitais
#  equipe: Luiza Seabra Batista Henriques Ramos
# aluno: Luiza Seabra Batista Henriques Ramos
# discente y
# aluna x

cota_init = float(input("valor da cota inicial\n"))

n_pav = int (input("Numero de pavimentos\n"))

pap = float(input("Valor da distância de piso a piso\n"))

cotas = []
for i in range(n_pav) :
    print(cota_init +(i * pap))
    cotas.append(cota_init +(i*pap))
    print (len(cotas))
    print (cotas)
